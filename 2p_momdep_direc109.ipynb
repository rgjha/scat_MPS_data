# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.executable
# Out:
# '/cm/shared/apps/conda-environments/python39/bin/python'

# %%
import os

# %%
import copy

# %%
os.environ["OMP_NUM_THREADS"] = "2"

# %%
import numpy as np
import scipy as sp
import scipy.linalg as la
import scipy.fft as fft
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import json

# %%
import evoMPS.tdvp_uniform as tdvp
import evoMPS.tdvp_sandwich as tdvp_s
import evoMPS.dynamics as dyn
import evoMPS.split_step as ss
import evoMPS.tdvp_common as tm
import evoMPS.matmul as mm
# Out:
# INFO: No c versions of epsilon maps. Compile extension modules for a boost at low bond-dimensions.

# %%
import sources.master as mas

# %%
import sources.post.overlaps as olaps

# %% [markdown]
# ## Load parameters and precomputed vacuum state

# %%
datadir = "./"
simbase = "direc109/"
simname = "maxD48_dt05RK4"
basedir = datadir + simbase
simdir = basedir + simname + "/"
mom = 0.526
t = 310
dt = 0.05
# Choose a time when the tracks are well-separated. Check if "P" is same for t \pm 20 to be sure.

# %%
with open(basedir + "/state_params.json", "r") as f:
    state_params = json.load(f)
state_params
# Out:
# {'J': 1.0,
#  'hx': 1.04,
#  'hz': 0.006,
#  'J2': 0.0,
#  'J3': 0.0,
#  'J4': 0.0,
#  'J5': 0.0,
#  'hzx': 0.0,
#  'D': 40,
#  'vac_tol': 1e-10,
#  'N': 1000,
#  'ortho_2p': True,
#  'symmB': False,
#  'pkt_numsites': 400,
#  'pkt_sigma': 70,
#  'pkt_midpt': 200,
#  'pad_mid': 0,
#  'pad_out': 0,
#  'momentum': 0.526,
#  'ex_lvl': 0}

# %%
ham = mas.get_ham(state_params["J"], state_params["hx"], state_params["hz"], state_params["J2"], state_params["J3"],
             state_params["J4"], state_params["J5"], state_params["hzx"])

# %%
vac = tdvp.EvoMPS_TDVP_Uniform.from_file(basedir + "vac_uniform.npy", ham)

# %%
vac.schmidt_sq()**0.5
# Out:
# array([9.77012805e-01+0.j, 2.11551497e-01+0.j, 2.55349139e-02+0.j,
#        5.71693481e-03+0.j, 2.59996270e-03+0.j, 6.30611601e-04+0.j,
#        2.42364596e-04+0.j, 7.65394958e-05+0.j, 6.12464160e-05+0.j,
#        2.14005307e-05+0.j, 1.80192119e-05+0.j, 8.29625711e-06+0.j,
#        5.60398011e-06+0.j, 2.06294664e-06+0.j, 1.78410558e-06+0.j,
#        8.80095644e-07+0.j, 6.77382645e-07+0.j, 4.96142563e-07+0.j,
#        2.28017080e-07+0.j, 1.84932355e-07+0.j, 1.53121793e-07+0.j,
#        8.74995343e-08+0.j, 6.24279374e-08+0.j, 4.35933796e-08+0.j,
#        2.64216122e-08+0.j, 2.31563876e-08+0.j, 1.68848224e-08+0.j,
#        1.31589783e-08+0.j, 7.85914743e-09+0.j, 6.78287374e-09+0.j,
#        6.08961995e-09+0.j, 5.26203760e-09+0.j, 3.75084528e-09+0.j,
#        2.80101156e-09+0.j, 2.16191767e-09+0.j, 1.79028661e-09+0.j,
#        1.50475627e-09+0.j, 8.94301593e-10+0.j, 7.40146365e-10+0.j,
#        5.55807672e-10+0.j])

# %% [markdown]
# ## Load state from simulation data

# %%
stepnum = int(t/dt)
stepnum
# Out:
# 6200

# %%
state = olaps.load_state(simdir + f"state_evo_step{stepnum}.npy", ham=ham)

# %% [markdown]
# # Compute overlaps with 2p position basis (naive)
# Ignoring momentum-dependence of excitation tensors for now.

# %%
ps = [mom]  # Compute overlaps using excitation tensors at these momenta.
num_ex = 2  # Use the first two excitation levels

# %% [markdown]
# This is the actual position-basis overlap computation:

# %%
psi, _, exlbls, sL, sR, BLs, BRs = olaps.overlap_2p_components_multip(
  state, vac, ps=ps, num_ex=num_ex, ortho=True,
  brute=True, force_pseudo=True, verbose=False,
  return_prep_data=True)
# Out:
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8070980187954673e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.4427527551730518e-06

# %%
exlbls  # Momentum and excitation number for each excitation-tensor label (final two axes of psi)
# Out:
# [(0.526, 0), (0.526, 1)]

# %%
psi_fn_comp = simdir + f"psi_comp_2p_nex{num_ex}_t{t}.npz"

# %%
# Save the position-basis wavefunction
np.savez_compressed(psi_fn_comp, psi=psi, exlbls=exlbls, BLs=BLs, BRs=BRs)

# %%
data = np.load(psi_fn_comp)
psi = data["psi"]
BLs = data["BLs"]
BRs = data["BRs"]
#data_ps = data["exlbls"][:,0]

# %%
psi.shape
# Out:
# (1001, 1001, 2, 2)

# %%
la.norm(np.nan_to_num(psi))
# Out:
# 0.5420811057413177

# %%
plt.imshow(abs(psi[:,:,0,0]), origin='lower')
plt.title("(1,1) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %%
psi_nn = np.nan_to_num(psi)
plt.plot([np.sum(abs(psi_nn[i,:,0,0])**2) for i in range(psi.shape[0])], label="particle 1")
plt.plot([np.sum(abs(psi_nn[:,i,0,0])**2) for i in range(psi.shape[1])], label="particle 2")
plt.legend()
plt.title(f"t={t}, (1,1) sector (naive)")
plt.xlabel("position")
plt.ylabel("probability")
plt.grid()

# %%
plt.imshow(abs(psi[:,:,0,1]), origin='lower')
plt.title("(1,2) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %%
psi_nn = np.nan_to_num(psi)
plt.plot([np.sum(abs(psi_nn[i,:,0,1])**2) for i in range(psi.shape[0])], label="particle 1")
plt.plot([np.sum(abs(psi_nn[:,i,0,1])**2) for i in range(psi.shape[1])], label="particle 2")
plt.legend()
plt.title(f"t={t}, (1,2) sector (naive)")
plt.xlabel("position")
plt.ylabel("probability")
plt.grid()

# %%
sum([i * np.sum(abs(psi_nn[i,:,0,1])**2) for i in range(psi.shape[0])])/la.norm(psi_nn[:,:,0,1])**2
# Out:
# 231.6359055777836

# %%
sum([i * np.sum(abs(psi_nn[:,i,0,1])**2) for i in range(psi.shape[1])])/la.norm(psi_nn[:,:,0,1])**2
# Out:
# 761.2122245812386

# %%
plt.imshow(abs(psi[:,:,1,0]), origin='lower')
plt.title("(2,1) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %%
psi_nn = np.nan_to_num(psi)
plt.plot([np.sum(abs(psi_nn[i,:,0,1])**2) for i in range(psi.shape[0])], "C0-", label="particle 1 (1,2)")
plt.plot([np.sum(abs(psi_nn[:,i,0,1])**2) for i in range(psi.shape[1])], "C1-", label="particle 2 (1,2)")
plt.plot([np.sum(abs(psi_nn[i,:,1,0])**2) for i in range(psi.shape[0])], "C1--", label="particle 1 (2,1)")
plt.plot([np.sum(abs(psi_nn[:,i,1,0])**2) for i in range(psi.shape[1])], "C0--", label="particle 2 (2,1)")
plt.legend()
plt.title(f"t={t}, (1,2) and (2,1) sectors (naive)")
plt.xlabel("position")
plt.ylabel("probability")
plt.grid()

# %%
plt.imshow(abs(psi[:,:,1,1]), origin='lower')
plt.title("(2,2) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %%
psi_nn = np.nan_to_num(psi)
plt.plot([np.sum(abs(psi_nn[i,:,1,1])**2) for i in range(psi.shape[0])], "C0-", label="particle 1")
plt.plot([np.sum(abs(psi_nn[:,i,1,1])**2) for i in range(psi.shape[1])], "C1-", label="particle 2")
plt.legend()
plt.title(f"t={t}, (2,2) sector (naive)")
plt.xlabel("position")
plt.ylabel("probability")
plt.grid()

# %% [markdown]
# ### Fourier transform (naive)

# %%
freqs = fft.fftfreq(psi.shape[0]) * (2*np.pi)

freqs = fft.fftshift(freqs)
psi_ = np.nan_to_num(psi)
nrm = la.norm(psi_)
psik = fft.fft2(psi_, axes=(0,1))
psik *= nrm/la.norm(psik)

psik = fft.fftshift(psik, axes=(0,1))

# %%
plt.imshow(abs(psik[:,:,0,0]), origin='lower', extent=[freqs[0], freqs[-1], freqs[0], freqs[-1]])
plt.title("(1,1) sector (naive)")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)
# Out:
# (-0.6, 0.6)

# %%
plt.imshow(abs(psik[:,:,0,1]), origin='lower', extent=[freqs[0], freqs[-1], freqs[0], freqs[-1]])
plt.title("(1,2) sector (naive)")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)
# Out:
# (-0.6, 0.6)

# %%
plt.imshow(abs(psik[:,:,1,0]), origin='lower', extent=[freqs[0], freqs[-1], freqs[0], freqs[-1]])
plt.title("(2,1) sector (naive)")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)
# Out:
# (-0.6, 0.6)

# %%
plt.imshow(abs(psik[:,:,1,1]), origin='lower', extent=[freqs[0], freqs[-1], freqs[0], freqs[-1]])
plt.title("(2,2) sector (naive)")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)
# Out:
# (-0.6, 0.6)

# %%
1 - la.norm(np.nan_to_num(psi))**2  # projection error (probability)
# Out:
# 0.7061480747982702

# %% [markdown]
# Mod over position, leaving separation.

# %%
nrms_allseps = olaps.nrms_by_sep(psi)

# %%
nrms_allseps.shape
# Out:
# (1001, 2, 2)

# %%
plt.plot(nrms_allseps[:,0,0]**2, label="(1,1)")
plt.plot(nrms_allseps[:,0,1]**2, label="(1,2)")
plt.plot(nrms_allseps[:,1,1]**2, label="(2,2)")
plt.xlabel("separation")
plt.ylabel("probability")
plt.legend()
plt.grid()

# %% [markdown]
# ## Now handle momentum dependence

# %%
ex_specs_L = [(-(mom), 0), (-(mom+0.04), 0), (-(mom-0.04), 0)] # we compute overlaps with excitation tensors for a few different momenta
ex_specs_R = [(mom, 0),  (mom+0.04, 0),  (mom-0.04, 0)]

# %%
psi_11, _, sL_11, sR_11, BLs_11, BRs_11 = olaps.overlap_2p_components_specs(
  state, vac, ex_specs_L, ex_specs_R, ortho=True,
  brute=True, force_pseudo=True, verbose=False,
  return_prep_data=True)
# Out:
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8037939105608954e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8063040070620756e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8114848557057533e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.4437074934451632e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.4479812469384325e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.4441619406639627e-06

# %% [markdown]
# Save everything:

# %%
psi_fn_comp = simdir + f"psi_comp_2p_11_basis_t{t}.npz"
np.savez_compressed(psi_fn_comp,
                  psi=psi_11, ex_specs_L=ex_specs_L, ex_specs_R=ex_specs_R,
                  BLs=BLs_11, BRs=BRs_11,
                  lL=sL_11.l[0], AL=sL_11.A[0], AC=vac.A[0], AR=sR_11.A[0], rR=sR_11.r[0])

# %%
psi_11_nn = np.nan_to_num(psi_11)

# %%
la.norm(np.nan_to_num(psi_11))
# Out:
# 0.8172563508963714

# %% [markdown]
# Let's plot the (still naive) position wavefunction for the momentum 0.4 tensors:

# %%
plt.imshow(abs(psi_11[:,:,0,0]), origin='lower')
plt.title("(1,1) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %% [markdown]
# Now the next component (which will be small due to orthonormalization).

# %%
plt.imshow(abs(psi_11[:,:,0,1]), origin='lower')
plt.title("(1,1) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %% [markdown]
# ## Actual Fourier-mode projection
#
# We use the data collected above, using a few momentum tensors, to parameterize the momentum-dependence on a fine grid (currently N momenta between -pi and pi, where N is the number of lattice sites in the sim. window).

# %% [markdown]
# This will take a while, as excitation tensor are computed for each of the N momenta.

# %%
res = olaps.get_overlaps_fourier(
    psi_11, sL_11, BLs_11, vac, BRs_11, sR_11,
    0, # left excitation level (adjust to match sector)
    0, # right excitation level (adjust to match sector)
    d_min=0, zero_tol=1e-6)
# Out:
# (1001, 1001, 3, 3) 0.6679079430804529 0.6679079430804529
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9976338080308203e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.999568477881448e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9769565181426654e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.978239280794041e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.997114543154908e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.975385786617926e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9859974300010292e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9797214764432367e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9753536404647635e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.984054532925769e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9708285720662544e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9661839521458937e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9747457980238495e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.969315005275664e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.961561254110043e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9555633273829565e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9565095944868862e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9404044536746924e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9517809669923046e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.942770502395631e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.938623997352543e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9403865035680187e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9363438833885728e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9232383698986295e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9281625656590135e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9135501066590065e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.921073386597304e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9160286144503593e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9147115205751566e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.905441613506973e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9051787448160063e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8997237074797625e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9001755379923612e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.9029488136222627e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.898843937076138e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8932604470814372e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.890523630327975e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8892116717200126e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.895807527224168e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8869789441456608e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.882285579367137e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8838817963243684e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.883344395922951e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8804492562571943e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.837824352897629e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8384464185825734e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.839253439412781e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8375188648743982e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8396158030814356e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8382481668376578e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8418797396719776e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8425725342368298e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8393133893241606e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8399044236180217e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8390969657934784e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8411581187888536e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.841479772277426e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.844850757874722e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8433742960099866e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8456947985268893e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.843583700314125e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8413698617752417e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8462826354397473e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8417818355396247e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8466140852906205e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8479545065163996e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2.8424989216838865e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 2
-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4120063574171495e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4120099765543893e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4119298289439662e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.410826127303289e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.411328054181343e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4111214706067805e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.411062694116565e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4111236631883647e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4101064733965353e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4508938863469078e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4417508124101538e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.453223248218852e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4472572881901907e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.448864599335017e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4574036708488893e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.458558905896128e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.454341054447268e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.456241136949005e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4552914274347758e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.459420408234443e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.462408009596319e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4639060433799836e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4653052914848987e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.465029340909104e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4723108279422765e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4699735345620777e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.476161303558028e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.476808775958757e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4791226942771693e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.484791299224252e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.480076947850296e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.483656946709053e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.490039541888374e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4873824866112982e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5022541542182997e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.4989478382007563e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5003744018750847e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5081689078904736e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5140183642249295e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5144718440666906e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5130536128111083e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5152446821594047e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.511118190459934e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.516932994446288e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5251387023795944e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5247168727745397e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.534762089511217e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.522064119046819e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.529703023797177e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5292123944608764e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.531116522471063e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5406110634297405e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.5311509144921335e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 3.533330559813747e-06

# %%
P_proj, P_red, P_sep, P_psi, psi_red, freqs_nonzero_L, freqs_nonzero_R, Bs_p_basis_L, Bs_p_basis_R = res

# %%
np.savez(simdir + f"psi_fourier_2p_11_basis_t{t}.npz", fL=freqs_nonzero_L, fR=freqs_nonzero_R, probs=res[:4], Bs_p_basis_L=Bs_p_basis_L, Bs_p_basis_R=Bs_p_basis_R)

# %%
P_psi # Raw probability including all excitation tensors.
# This is typically an overestimate, as the basis is capable of representing excitations in other sectors too.
# Out:
# 0.6679079430804529

# %%
P_sep  # After dropping poorly-separated terms
# Out:
# 0.6679079430804529

# %%
P_proj  # This is the final probability after accounting for momentum dependence.
# Out:
# 0.5580377036510072

# %%
la.norm(psik[:,:,0,0])**2  # Single-tensor (naive) probability of (1,1) from previous computation
# Out:
# 0.17368180963635532

# %%
psi_red.shape
# Out:
# (163, 166)

# %%
plt.semilogy(freqs_nonzero_L, 1-la.norm(Bs_p_basis_L, axis=2)[:,0], ".")
plt.semilogy(freqs_nonzero_R, 1-la.norm(Bs_p_basis_R, axis=2)[:,0], ".")
plt.xlabel("momentum")
plt.ylabel("excitation-basis projection error")
plt.grid()

# %% [markdown]
# Projections are very accurate for momenta close to +/- 0.5. Also not too bad beyond.

# %%
# NOTE: assuming here, for plotting purposes, that freqs_nonzero_X is continuous and sorted
plt.imshow(abs(psi_red), origin='lower',
           extent=(freqs_nonzero_R[0], freqs_nonzero_R[-1], freqs_nonzero_L[0], freqs_nonzero_L[-1]))
plt.title("(1,1) sector")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
#plt.xlim(-0.5,0.5)
#plt.ylim(-0.5,0.5)

# %%
plt.plot(freqs_nonzero_L, [np.sum(abs(psi_red[i,:])**2) for i in range(psi_red.shape[0])], ".:", label="particle 1")
plt.plot(freqs_nonzero_R, [np.sum(abs(psi_red[:,i])**2) for i in range(psi_red.shape[1])], ".:", label="particle 2")
plt.legend()
plt.title(f"t={t}, (1,1) sector")
plt.xlabel("momentum")
plt.ylabel("probability")
plt.xlim(-0.75,0.75)
plt.grid()

# %%
plt.plot(freqs, [np.sum(abs(psik[i,:,0,0])**2) for i in range(psik.shape[0])], ".:", label="particle 1")
plt.plot(freqs, [np.sum(abs(psik[:,i,0,0])**2) for i in range(psik.shape[1])], ".:", label="particle 2")
plt.legend()
plt.title(f"t={t}, (1,1) sector (naive)")
plt.xlabel("momentum")
plt.ylabel("probability")
plt.xlim(-0.75,0.75)
plt.grid()
