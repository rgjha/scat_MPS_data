# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.executable
# Out:
# '/cm/shared/apps/conda-environments/python39/bin/python'

# %%
import os

# %%
import copy

# %%
os.environ["OMP_NUM_THREADS"] = "2"

# %%
import numpy as np
import scipy as sp
import scipy.linalg as la
import scipy.fft as fft
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import json

# %%
import evoMPS.tdvp_uniform as tdvp
import evoMPS.tdvp_sandwich as tdvp_s
import evoMPS.dynamics as dyn
import evoMPS.split_step as ss
import evoMPS.tdvp_common as tm
import evoMPS.matmul as mm
# Out:
# INFO: No c versions of epsilon maps. Compile extension modules for a boost at low bond-dimensions.

# %%
import sources.master as mas

# %%
import sources.post.overlaps as olaps

# %% [markdown]
# ## Load parameters and precomputed vacuum state

# %%
datadir = "./"
simbase = "direc104/"
simname = "maxD64_dt05RK4"
basedir = datadir + simbase
simdir = basedir + simname + "/"
mom = 0.53
t = 300
# Choose a time when the tracks are well-separated. Check if "P" is same for t \pm 20 to be sure.

# %%
with open(basedir + "/state_params.json", "r") as f:
    state_params = json.load(f)
state_params
# Out:
# {'J': 1.0,
#  'hx': 1.1568,
#  'hz': 0.006,
#  'J2': 0.0,
#  'J3': 0.0,
#  'J4': 0.0,
#  'J5': 0.0,
#  'hzx': 0.0,
#  'D': 40,
#  'vac_tol': 1e-10,
#  'N': 1000,
#  'ortho_2p': True,
#  'symmB': False,
#  'pkt_numsites': 400,
#  'pkt_sigma': 70,
#  'pkt_midpt': 200,
#  'pad_mid': 0,
#  'pad_out': 0,
#  'momentum': 0.53,
#  'ex_lvl': 0}

# %%
ham = mas.get_ham(state_params["J"], state_params["hx"], state_params["hz"], state_params["J2"], state_params["J3"],
             state_params["J4"], state_params["J5"], state_params["hzx"])

# %%
vac = tdvp.EvoMPS_TDVP_Uniform.from_file(basedir + "vac_uniform.npy", ham)

# %%
vac.schmidt_sq()**0.5
# Out:
# array([9.63144211e-01+0.j, 2.67966575e-01+0.j, 2.24455309e-02+0.j,
#        6.29865239e-03+0.j, 1.83516906e-03+0.j, 5.24277466e-04+0.j,
#        1.48864217e-04+0.j, 4.38321951e-05+0.j, 4.26694267e-05+0.j,
#        1.24215752e-05+0.j, 1.20543321e-05+0.j, 3.60596263e-06+0.j,
#        3.47801633e-06+0.j, 1.03122748e-06+0.j, 9.79244902e-07+0.j,
#        2.94431873e-07+0.j, 2.89524760e-07+0.j, 2.83087664e-07+0.j,
#        8.51269996e-08+0.j, 8.35181260e-08+0.j, 7.96748102e-08+0.j,
#        2.40009406e-08+0.j, 2.37033674e-08+0.j, 2.30642997e-08+0.j,
#        7.08653604e-09+0.j, 6.92805616e-09+0.j, 6.81888899e-09+0.j,
#        6.38381321e-09+0.j, 2.03748647e-09+0.j, 1.92609900e-09+0.j,
#        1.90198329e-09+0.j, 1.87070357e-09+0.j, 1.83758027e-09+0.j,
#        5.75040628e-10+0.j, 5.57201247e-10+0.j, 5.53153621e-10+0.j,
#        5.38967001e-10+0.j, 3.77448938e-10+0.j, 1.66480029e-10+0.j,
#        1.46066272e-10+0.j])

# %% [markdown]
# ## Load state from simulation data

# %%
dt = 0.05
stepnum = int(t/dt)
stepnum
# Out:
# 6000

# %%
state = olaps.load_state(simdir + f"state_evo_step{stepnum}.npy", ham=ham)

# %% [markdown]
# # Compute overlaps with 2p position basis (naive)
# Ignoring momentum-dependence of excitation tensors for now.

# %%
ps = [mom]  # Compute overlaps using excitation tensors at these momenta.
num_ex = 2  # Use the first two excitation levels

# %% [markdown]
# This is the actual position-basis overlap computation:

# %%
psi, _, exlbls, sL, sR, BLs, BRs = olaps.overlap_2p_components_multip(
  state, vac, ps=ps, num_ex=num_ex, ortho=True,
  brute=True, force_pseudo=True, verbose=False,
  return_prep_data=True)
# Out:
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.1891176592101817e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 7.628348316423472e-06
# Warning! BL1 LGF failed: 1.2683287345711907e-10
# Warning! B1s[1] LGF failed: 1.2683287345711907e-10

# %%
exlbls  # Momentum and excitation number for each excitation-tensor label (final two axes of psi)
# Out:
# [(0.53, 0), (0.53, 1)]

# %%
psi_fn_comp = simdir + f"psi_comp_2p_nex{num_ex}_t{t}.npz"

# %%
# Save the position-basis wavefunction
np.savez_compressed(psi_fn_comp, psi=psi, exlbls=exlbls, BLs=BLs, BRs=BRs)

# %%
data = np.load(psi_fn_comp)
psi = data["psi"]
BLs = data["BLs"]
BRs = data["BRs"]
#data_ps = data["exlbls"][:,0]

# %%
psi.shape
# Out:
# (1001, 1001, 2, 2)

# %%
la.norm(np.nan_to_num(psi))
# Out:
# 0.6634389269174923

# %%
plt.imshow(abs(psi[:,:,0,0]), origin='lower')
plt.title("(1,1) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %%
psi_nn = np.nan_to_num(psi)
plt.plot([np.sum(abs(psi_nn[i,:,0,0])**2) for i in range(psi.shape[0])], label="particle 1")
plt.plot([np.sum(abs(psi_nn[:,i,0,0])**2) for i in range(psi.shape[1])], label="particle 2")
plt.legend()
plt.title(f"t={t}, (1,1) sector (naive)")
plt.xlabel("position")
plt.ylabel("probability")
plt.grid()

# %%
plt.imshow(abs(psi[:,:,0,1]), origin='lower')
plt.title("(1,2) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %%
psi_nn = np.nan_to_num(psi)
plt.plot([np.sum(abs(psi_nn[i,:,0,1])**2) for i in range(psi.shape[0])], label="particle 1")
plt.plot([np.sum(abs(psi_nn[:,i,0,1])**2) for i in range(psi.shape[1])], label="particle 2")
plt.legend()
plt.title(f"t={t}, (1,2) sector (naive)")
plt.xlabel("position")
plt.ylabel("probability")
plt.grid()

# %%
sum([i * np.sum(abs(psi_nn[i,:,0,1])**2) for i in range(psi.shape[0])])/la.norm(psi_nn[:,:,0,1])**2
# Out:
# 227.22989724369543

# %%
sum([i * np.sum(abs(psi_nn[:,i,0,1])**2) for i in range(psi.shape[1])])/la.norm(psi_nn[:,:,0,1])**2
# Out:
# 772.2624967136373

# %%
plt.imshow(abs(psi[:,:,1,0]), origin='lower')
plt.title("(2,1) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %%
psi_nn = np.nan_to_num(psi)
plt.plot([np.sum(abs(psi_nn[i,:,0,1])**2) for i in range(psi.shape[0])], "C0-", label="particle 1 (1,2)")
plt.plot([np.sum(abs(psi_nn[:,i,0,1])**2) for i in range(psi.shape[1])], "C1-", label="particle 2 (1,2)")
plt.plot([np.sum(abs(psi_nn[i,:,1,0])**2) for i in range(psi.shape[0])], "C1--", label="particle 1 (2,1)")
plt.plot([np.sum(abs(psi_nn[:,i,1,0])**2) for i in range(psi.shape[1])], "C0--", label="particle 2 (2,1)")
plt.legend()
plt.title(f"t={t}, (1,2) and (2,1) sectors (naive)")
plt.xlabel("position")
plt.ylabel("probability")
plt.grid()

# %%
plt.imshow(abs(psi[:,:,1,1]), origin='lower')
plt.title("(2,2) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %%
psi_nn = np.nan_to_num(psi)
plt.plot([np.sum(abs(psi_nn[i,:,1,1])**2) for i in range(psi.shape[0])], "C0-", label="particle 1")
plt.plot([np.sum(abs(psi_nn[:,i,1,1])**2) for i in range(psi.shape[1])], "C1-", label="particle 2")
plt.legend()
plt.title(f"t={t}, (2,2) sector (naive)")
plt.xlabel("position")
plt.ylabel("probability")
plt.grid()

# %% [markdown]
# ### Fourier transform (naive)

# %%
freqs = fft.fftfreq(psi.shape[0]) * (2*np.pi)

freqs = fft.fftshift(freqs)
psi_ = np.nan_to_num(psi)
nrm = la.norm(psi_)
psik = fft.fft2(psi_, axes=(0,1))
psik *= nrm/la.norm(psik)

psik = fft.fftshift(psik, axes=(0,1))

# %%
plt.imshow(abs(psik[:,:,0,0]), origin='lower', extent=[freqs[0], freqs[-1], freqs[0], freqs[-1]])
plt.title("(1,1) sector (naive)")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)
# Out:
# (-0.6, 0.6)

# %%
plt.imshow(abs(psik[:,:,0,1]), origin='lower', extent=[freqs[0], freqs[-1], freqs[0], freqs[-1]])
plt.title("(1,2) sector (naive)")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)
# Out:
# (-0.6, 0.6)

# %%
plt.imshow(abs(psik[:,:,1,0]), origin='lower', extent=[freqs[0], freqs[-1], freqs[0], freqs[-1]])
plt.title("(2,1) sector (naive)")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)
# Out:
# (-0.6, 0.6)

# %%
plt.imshow(abs(psik[:,:,1,1]), origin='lower', extent=[freqs[0], freqs[-1], freqs[0], freqs[-1]])
plt.title("(2,2) sector (naive)")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)
# Out:
# (-0.6, 0.6)

# %%
1 - la.norm(np.nan_to_num(psi))**2  # projection error (probability)
# Out:
# 0.5598487902505663

# %% [markdown]
# Mod over position, leaving separation.

# %%
nrms_allseps = olaps.nrms_by_sep(psi)

# %%
nrms_allseps.shape
# Out:
# (1001, 2, 2)

# %%
plt.plot(nrms_allseps[:,0,0]**2, label="(1,1)")
plt.plot(nrms_allseps[:,0,1]**2, label="(1,2)")
plt.plot(nrms_allseps[:,1,1]**2, label="(2,2)")
plt.xlabel("separation")
plt.ylabel("probability")
plt.legend()
plt.grid()

# %% [markdown]
# ## Now handle momentum dependence

# %%
ex_specs_L = [(-(mom), 0), (-(mom+0.04), 0), (-(mom-0.04), 0)] # we compute overlaps with excitation tensors for a few different momenta
ex_specs_R = [(mom, 0),  (mom+0.04, 0),  (mom-0.04, 0)]

# %%
psi_11, _, sL_11, sR_11, BLs_11, BRs_11 = olaps.overlap_2p_components_specs(
  state, vac, ex_specs_L, ex_specs_R, ortho=True,
  brute=True, force_pseudo=True, verbose=False,
  return_prep_data=True)
# Out:
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.1887359512369268e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.1889366380190832e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.1892417056825331e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 7.631966606329881e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 7.62888426111234e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 7.624445900742865e-06

# %% [markdown]
# Save everything:

# %%
psi_fn_comp = simdir + f"psi_comp_2p_11_basis_t{t}.npz"
np.savez_compressed(psi_fn_comp,
                  psi=psi_11, ex_specs_L=ex_specs_L, ex_specs_R=ex_specs_R,
                  BLs=BLs_11, BRs=BRs_11,
                  lL=sL_11.l[0], AL=sL_11.A[0], AC=vac.A[0], AR=sR_11.A[0], rR=sR_11.r[0])

# %%
psi_11_nn = np.nan_to_num(psi_11)

# %%
la.norm(np.nan_to_num(psi_11))
# Out:
# 0.9351892813725416

# %% [markdown]
# Let's plot the (still naive) position wavefunction for the momentum 0.4 tensors:

# %%
plt.imshow(abs(psi_11[:,:,0,0]), origin='lower')
plt.title("(1,1) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %% [markdown]
# Now the next component (which will be small due to orthonormalization).

# %%
plt.imshow(abs(psi_11[:,:,0,1]), origin='lower')
plt.title("(1,1) sector (naive)")
plt.xlabel("position of particle 2")
plt.ylabel("position of particle 1")
plt.colorbar()

# %% [markdown]
# ## Actual Fourier-mode projection
#
# We use the data collected above, using a few momentum tensors, to parameterize the momentum-dependence on a fine grid (currently N momenta between -pi and pi, where N is the number of lattice sites in the sim. window).

# %% [markdown]
# This will take a while, as excitation tensor are computed for each of the N momenta.

# %%
res = olaps.get_overlaps_fourier(
    psi_11, sL_11, BLs_11, vac, BRs_11, sR_11,
    0, # left excitation level (adjust to match sector)
    0, # right excitation level (adjust to match sector)
    d_min=0, zero_tol=1e-6)
# Out:
# (1001, 1001, 3, 3) 0.8745789919940908 0.8745789919940908
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2086409045945669e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2086478825893241e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2087316303694125e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2087430032034211e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2088849304611079e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.208614281959259e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2019462371767233e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2016686839495728e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.202109750761687e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2020528398565186e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2016978975286307e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2020851564919808e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.201808167936589e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2022994728476814e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.202286316885373e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2019005593931734e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2023389107814364e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2024072621826493e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2024487482248313e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2025366203455707e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2024996125457604e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2026846324175893e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2026217049768966e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2026342511867682e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.202884436821917e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2029071365545853e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2030183536095588e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2028568322490054e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2032158898571724e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2030187999415323e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2034554352145522e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2032347738896596e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.203573271650805e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2034151431040949e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.203284892069829e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2039029884861439e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2036988761852438e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.204358475728608e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2040796206206624e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2043113883419291e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2044064644706285e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2040387560214363e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2047601783762214e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2041878998184674e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2042776838901489e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2041956128014509e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.204305277821333e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2042834577585696e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2048285159133982e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.204496696414083e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.205204737576051e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2053561000690545e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2050182457219531e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2053773771605293e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.205461019977112e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2054654031408215e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2059220644616663e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2059688527879037e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2056825718480024e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2084185896976435e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 1.2083685629514503e-05
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 6.005393774021954e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 6.004719329598111e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 6.0019664086215185e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 6.002077704682325e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.9485131031985e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.9463846538937405e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.9542850842294904e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.945656316740003e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.931087644347725e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.934816488414107e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.935187320739901e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.9277171273625004e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.931257455107866e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.934043680735194e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.9237852279779375e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.91630413601754e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.925386560651379e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.90922501073092e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.923832875311944e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.908909891991168e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.914083369967318e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.907232433510268e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.897444555421016e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.909029511492347e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.897927673671698e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.8959529847690946e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.890849291788335e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.901439729819423e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.899972223706831e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.891588285474719e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.898276866060164e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.891144451184957e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.882395273462124e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.8877144333311794e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.888626188995482e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.8835321092275994e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.876503383670262e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.875483655340999e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.8730494083260535e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.873070332554872e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.877613204983914e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.870716148480416e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.875784779764933e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.866553008107254e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.871771015030744e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.8707333515028275e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.868410940110146e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.867929290831712e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.866539473345974e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.865132794938984e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.8643603593257435e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.86405436236332e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.85403683472329e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.852237861052079e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.859262581025775e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.851598162064619e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.855937190848291e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.859677741700753e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.850658986806618e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 6.002231529212232e-06
# WARNING:evoMPS.tdvp_uniform:Warning! H is not Hermitian! 5.998894746878067e-06

# %%
P_proj, P_red, P_sep, P_psi, psi_red, freqs_nonzero_L, freqs_nonzero_R, Bs_p_basis_L, Bs_p_basis_R = res

# %%
np.savez(simdir + f"psi_fourier_2p_11_basis_t{t}.npz", fL=freqs_nonzero_L, fR=freqs_nonzero_R, probs=res[:4], Bs_p_basis_L=Bs_p_basis_L, Bs_p_basis_R=Bs_p_basis_R)

# %%
P_psi # Raw probability including all excitation tensors.
# This is typically an overestimate, as the basis is capable of representing excitations in other sectors too.
# Out:
# 0.8745789919940908

# %%
P_sep  # After dropping poorly-separated terms
# Out:
# 0.8745789919940908

# %%
P_proj  # This is the final probability after accounting for momentum dependence.
# Out:
# 0.8742597518581541

# %%
la.norm(psik[:,:,0,0])**2  # Single-tensor (naive) probability of (1,1) from previous computation
# Out:
# 0.4311421672127977

# %%
psi_red.shape
# Out:
# (61, 61)

# %%
plt.semilogy(freqs_nonzero_L, 1-la.norm(Bs_p_basis_L, axis=2)[:,0], ".")
plt.semilogy(freqs_nonzero_R, 1-la.norm(Bs_p_basis_R, axis=2)[:,0], ".")
plt.xlabel("momentum")
plt.ylabel("excitation-basis projection error")
plt.grid()

# %% [markdown]
# Projections are very accurate for momenta close to +/- 0.5. Also not too bad beyond.

# %%
# NOTE: assuming here, for plotting purposes, that freqs_nonzero_X is continuous and sorted
plt.imshow(abs(psi_red), origin='lower',
           extent=(freqs_nonzero_R[0], freqs_nonzero_R[-1], freqs_nonzero_L[0], freqs_nonzero_L[-1]))
plt.title("(1,1) sector")
plt.xlabel("momentum of particle 2")
plt.ylabel("momentum of particle 1")
plt.colorbar()
#plt.xlim(-0.5,0.5)
#plt.ylim(-0.5,0.5)

# %%
plt.plot(freqs_nonzero_L, [np.sum(abs(psi_red[i,:])**2) for i in range(psi_red.shape[0])], ".:", label="particle 1")
plt.plot(freqs_nonzero_R, [np.sum(abs(psi_red[:,i])**2) for i in range(psi_red.shape[1])], ".:", label="particle 2")
plt.legend()
plt.title(f"t={t}, (1,1) sector")
plt.xlabel("momentum")
plt.ylabel("probability")
plt.xlim(-0.75,0.75)
plt.grid()

# %%
plt.plot(freqs, [np.sum(abs(psik[i,:,0,0])**2) for i in range(psik.shape[0])], ".:", label="particle 1")
plt.plot(freqs, [np.sum(abs(psik[:,i,0,0])**2) for i in range(psik.shape[1])], ".:", label="particle 2")
plt.legend()
plt.title(f"t={t}, (1,1) sector (naive)")
plt.xlabel("momentum")
plt.ylabel("probability")
plt.xlim(-0.75,0.75)
plt.grid()
